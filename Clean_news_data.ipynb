# %%
import pandas as pd

# %%
data_news= pd.read_csv('./data/debug_ticker-news_data.csv')

# %%
data_news["date"]= pd.to_datetime( data_news["date"],infer_datetime_format=True)

data_news_one= data_news.drop(columns= ['image_url','type','news_id','eventid'])

# %%
data_news_one
# Out:
#                                               news_url  \
# 0    https://www.coindesk.com/podcasts/coindesk-pod...
# 1    https://cointelegraph.com/news/btc-price-slips...
# 2    https://news.bitcoin.com/an-in-depth-look-at-b...
# 3    https://dailyhodl.com/2021/08/15/is-bitcoin-do...
# 4    https://ambcrypto.com/heres-everything-you-nee...
# ..                                                 ...
# 295  https://www.cryptopolitan.com/dogecoin-price-a...
# 296  https://thecurrencyanalytics.com/altcoins/most...
# 297  https://www.dcforecasts.com/dogecoin-news/doge...
# 298  https://www.benzinga.com/markets/cryptocurrenc...
# 299  https://investorplace.com/2021/08/btc-eth-ada-...
#
#                                                  title  \
# 0              Why Bitcoin Matters in Nigeria and Iraq
# 1    BTC price slips under $46K but analysts are be...
# 2    An In Depth Look at Bitcoin's First Chain Spli...
# 3    Is Bitcoin Doing a Head Fake? On-Chain Analyst...
# 4    Here's everything you need to know about Bitco...
# ..                                                 ...
# 295  Dogecoin Price Analysis: DOGE spikes to $0.29,...
# 296  Most People Don't Understand How Big DogeCoin ...
# 297  DOGE Rises Further Than The Market After 41% S...
# 298  Ethereum Is A 'Scam?' Twitter CEO Takes To Tro...
# 299  BTC, ETH, ADA, DOGE: Why Is the Crypto Market ...
#
#                                                   text  \
# 0    A reading of two essays from crypto voices aro...
# 1    A dip below $46,000 has little impact on senti...
# 2    Since January 3, 2009, the Bitcoin network has...
# 3    Prominent on-chain analyst Will Clemente is we...
# 4    The last few days have been pretty slippery fo...
# ..                                                 ...
# 295  TL;DR Breakdown DOGE rallied to the $0.29 mark...
# 296  Catch up on the latest crypto market news at T...
# 297  DOGE rises further than the entire crypto mark...
# 298          Twitter Inc. (NYSE: TWTR) and Square Inc.
# 299  Why is the crypto market down today? Bitcoin i...
#
#                 source_name                      date         topics  \
# 0                  Coindesk 2021-08-15 09:45:13-04:00             []
# 1             Cointelegraph 2021-08-15 05:36:18-04:00             []
# 2                   Bitcoin 2021-08-15 09:30:37-04:00             []
# 3            The Daily Hodl 2021-08-15 05:00:45-04:00             []
# 4                 AMBCrypto 2021-08-15 11:00:16-04:00             []
# ..                      ...                       ...            ...
# 295           Cryptopolitan 2021-08-12 09:28:24-04:00  ['tanalysis']
# 296  The Currency Analytics 2021-08-12 13:00:34-04:00             []
# 297             DCForecasts 2021-08-12 06:25:04-04:00             []
# 298                Benzinga 2021-08-12 05:38:18-04:00             []
# 299           Investorplace 2021-08-12 13:52:25-04:00             []
#
#     sentiment                        tickers  rank_score
# 0     Neutral                        ['BTC']        6.28
# 1    Positive                        ['BTC']        6.22
# 2    Positive                        ['BTC']        6.13
# 3    Positive                        ['BTC']        6.04
# 4     Neutral                        ['BTC']        6.01
# ..        ...                            ...         ...
# 295  Positive                       ['DOGE']        5.37
# 296  Positive                       ['DOGE']        4.93
# 297  Positive                       ['DOGE']        4.90
# 298   Neutral                ['DOGE', 'ETH']        4.45
# 299  Negative  ['ADA', 'BTC', 'DOGE', 'ETH']        4.27
#
# [300 rows x 9 columns]
