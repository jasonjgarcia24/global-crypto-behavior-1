# %%
import pandas as pd

# %%
def data_pull(date_var):
    data_crypto_news = pd.read_csv(f"./data/ticker-news_data_{date_var}.csv")
    data_crypto_news["date"]= pd.to_datetime( data_crypto_news["date"],infer_datetime_format=True)
    data_crypto_news= data_crypto_news.drop(columns= ['image_url','type','news_id','eventid'])
    return data_crypto_news

# %%
Crypto_news_df = data_pull("20210815")
Crypto_news_df
# Out:
#                                                news_url  \
# 0     https://www.coindesk.com/podcasts/coindesk-pod...
# 1     https://cointelegraph.com/news/gosats-launches...
# 2     https://cointelegraph.com/news/btc-price-slips...
# 3     https://news.bitcoin.com/an-in-depth-look-at-b...
# 4     https://dailyhodl.com/2021/08/15/is-bitcoin-do...
# ...                                                 ...
# 1195  https://www.cryptopolitan.com/dogecoin-price-a...
# 1196  https://thecurrencyanalytics.com/altcoins/most...
# 1197  https://www.dcforecasts.com/dogecoin-news/doge...
# 1198  https://www.benzinga.com/markets/cryptocurrenc...
# 1199  https://investorplace.com/2021/08/btc-eth-ada-...
#
#                                                   title  \
# 0               Why Bitcoin Matters in Nigeria and Iraq
# 1     GoSats launches Bitcoin cashback rewards card ...
# 2     BTC price slips under $46K but analysts are be...
# 3     An In Depth Look at Bitcoin's First Chain Spli...
# 4     Is Bitcoin Doing a Head Fake? On-Chain Analyst...
# ...                                                 ...
# 1195  Dogecoin Price Analysis: DOGE spikes to $0.29,...
# 1196  Most People Don't Understand How Big DogeCoin ...
# 1197  DOGE Rises Further Than The Market After 41% S...
# 1198  Ethereum Is A 'Scam?' Twitter CEO Takes To Tro...
# 1199  BTC, ETH, ADA, DOGE: Why Is the Crypto Market ...
#
#                                                    text  \
# 0     A reading of two essays from crypto voices aro...
# 1     Users will be able to earn yield paid in BTC o...
# 2     A dip below $46,000 has little impact on senti...
# 3     Since January 3, 2009, the Bitcoin network has...
# 4     Prominent on-chain analyst Will Clemente is we...
# ...                                                 ...
# 1195  TL;DR Breakdown DOGE rallied to the $0.29 mark...
# 1196  Catch up on the latest crypto market news at T...
# 1197  DOGE rises further than the entire crypto mark...
# 1198          Twitter Inc. (NYSE: TWTR) and Square Inc.
# 1199  Why is the crypto market down today? Bitcoin i...
#
#                  source_name                      date         topics  \
# 0                   Coindesk 2021-08-15 09:45:13-04:00             []
# 1              Cointelegraph 2021-08-15 13:00:00-04:00             []
# 2              Cointelegraph 2021-08-15 05:36:18-04:00             []
# 3                    Bitcoin 2021-08-15 09:30:37-04:00             []
# 4             The Daily Hodl 2021-08-15 05:00:45-04:00             []
# ...                      ...                       ...            ...
# 1195           Cryptopolitan 2021-08-12 09:28:24-04:00  ['tanalysis']
# 1196  The Currency Analytics 2021-08-12 13:00:34-04:00             []
# 1197             DCForecasts 2021-08-12 06:25:04-04:00             []
# 1198                Benzinga 2021-08-12 05:38:18-04:00             []
# 1199           Investorplace 2021-08-12 13:52:25-04:00             []
#
#      sentiment                        tickers  rank_score
# 0      Neutral                        ['BTC']        6.28
# 1     Positive                        ['BTC']        6.22
# 2     Positive                        ['BTC']        6.22
# 3     Positive                        ['BTC']        6.13
# 4     Positive                        ['BTC']        6.04
# ...        ...                            ...         ...
# 1195  Positive                       ['DOGE']        5.37
# 1196  Positive                       ['DOGE']        4.93
# 1197  Positive                       ['DOGE']        4.90
# 1198   Neutral                ['DOGE', 'ETH']        4.45
# 1199  Negative  ['ADA', 'BTC', 'DOGE', 'ETH']        4.27
#
# [1200 rows x 9 columns]
