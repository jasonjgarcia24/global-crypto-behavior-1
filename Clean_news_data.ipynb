# %%
import pandas as pd

# %%
data_news= pd.read_csv('../data/debug_news-listings_data.csv')

# %%
data_news["date"]= pd.to_datetime( data_news["date"],infer_datetime_format=True)

data_news_one= data_news.drop(columns= ['image_url','type','news_id','eventid'])

# %%
data_news_one
# Out:
#      Unnamed: 0                                           news_url  \
# 0             0  https://cointelegraph.com/news/wealth-managers...
# 1             1  https://www.benzinga.com/markets/cryptocurrenc...
# 2             2  https://cointelegraph.com/news/btc-price-passe...
# 3             3  https://cointelegraph.com/news/cause-and-effec...
# 4             4  https://cointelegraph.com/news/bitcoin-s-off-c...
# ..          ...                                                ...
# 295          45  https://www.benzinga.com/markets/cryptocurrenc...
# 296          46  https://www.benzinga.com/markets/cryptocurrenc...
# 297          47  https://www.benzinga.com/markets/cryptocurrenc...
# 298          48  https://cointelegraph.com/news/price-analysis-...
# 299          49  https://dailyhodl.com/2021/08/11/top-analyst-p...
#
#                                                  title  \
# 0    Wealth managers gain exposure to Bitcoin via G...
# ...
