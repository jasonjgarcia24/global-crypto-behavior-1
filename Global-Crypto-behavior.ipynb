# %% [markdown]
# # Global Crypto Behavior Analyzer

# %%
import pandas as pd

from datetime import datetime

from pathlib import Path

# %%
news_df = pd.read_csv(Path("./data/ticker-news_data_20210816.csv"))
news_df.tail()
# Out:
#                                                 news_url  \
# 10552  https://decrypt.co/60202/dallas-mavericks-now-...
# 10553  https://cryptobriefing.com/mark-cubans-dallas-...
# 10554  https://ambcrypto.com/mark-cubans-dallas-maver...
# 10555  https://cryptoticker.io/en/nba-team-dallas-mav...
# 10556  https://cryptobriefing.com/dogecoin-will-be-av...
#
#                                                image_url  \
# 10552  https://crypto.snapi.dev/images/v1/2/k/dallas-...
# 10553  https://crypto.snapi.dev/images/v1/c/a/basketd...
# 10554  https://crypto.snapi.dev/images/v1/i/7/basketb...
# 10555  https://crypto.snapi.dev/images/v1/o/o/puppy-1...
# 10556  https://crypto.snapi.dev/images/v1/j/q/elon-mu...
#
#                                                    title  \
# 10552  Dallas Mavericks Now Accepting Dogecoin as Pay...
# 10553  Mark Cuban's Dallas Mavericks Will Accept Doge...
# 10554  Mark Cuban's Dallas Mavericks will now accept ...
# ...
