# %% [markdown]
# # Global Crypto Behavior Analyzer

# %%
from market_response.crypto import CoinMarketCapResponse

cryptocurrencies = {
    "Bitcoin": "BTC",
    "Ethereum": "ETH",
    "Cardano": "ADA",
    "Litecoin": "LTC",
    "Ripple": "XRP",
    "Monero": "XMR",
    "Dogecoin": "DOGE",
    "Filecoin": "FIL"
}

slugs, tickers = list(zip(*cryptocurrencies.items()))
coins          = 5000
currency       = "USD"
endpoint       = "listings/latest"

data = CoinMarketCapResponse(tickers, slugs,  coins, currency, endpoint,
                             make_request=True, debug="YES")

data.dataframe
# Out:
#       id      name symbol      slug  num_market_pairs  \
# 0      1   Bitcoin    BTC   bitcoin              8935
# 1   1027  Ethereum    ETH  ethereum              5630
# 4   2010   Cardano    ADA   cardano               284
# 6     74  Dogecoin   DOGE  dogecoin               378
# 13     2  Litecoin    LTC  litecoin               710
# 23  2280  Filecoin    FIL  filecoin               148
# 27   328    Monero    XMR    monero               162
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 4   2017-10-01T00:00:00.000Z
# 6   2013-12-15T00:00:00.000Z
# 13  2013-04-28T00:00:00.000Z
# 23  2017-12-13T00:00:00.000Z
# 27  2014-05-21T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [mineable, pow, smart-contracts, ethereum, coi...           NaN
# 4   [mineable, dpos, pos, platform, research, smar...  4.500000e+10
# 6   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 13  [mineable, pow, scrypt, medium-of-exchange, bi...  8.400000e+07
# 23  [mineable, distributed-computing, filesharing,...           NaN
# 27  [mineable, pow, medium-of-exchange, privacy, r...           NaN
#
#     circulating_supply  total_supply platform  cmc_rank  \
# 0         1.878211e+07  1.878211e+07     None         1
# 1         1.170489e+08  1.170489e+08     None         2
# 4         3.209673e+10  3.298224e+10     None         5
# 6         1.307996e+11  1.307996e+11     None         7
# 13        6.675261e+07  6.675261e+07     None        14
# 23        9.536228e+07  9.536228e+07     None        24
# 27        1.797043e+07  1.797043e+07     None        28
#
#                 last_updated  \
# 0   2021-08-10T17:56:02.000Z
# 1   2021-08-10T17:56:02.000Z
# 4   2021-08-10T17:55:09.000Z
# 6   2021-08-10T17:56:03.000Z
# 13  2021-08-10T17:56:02.000Z
# 23  2021-08-10T17:56:04.000Z
# 27  2021-08-10T17:56:04.000Z
#
#                                                 quote
# 0   {'USD': {'price': 45026.29477360262, 'volume_2...
# 1   {'USD': {'price': 3093.334931102753, 'volume_2...
# 4   {'USD': {'price': 1.55979115557864, 'volume_24...
# 6   {'USD': {'price': 0.24798973814074, 'volume_24...
# 13  {'USD': {'price': 161.31597001680163, 'volume_...
# 23  {'USD': {'price': 66.13823922818833, 'volume_2...
# 27  {'USD': {'price': 260.8547681294421, 'volume_2...

# %%
type(data)
# Out:
# market_response.crypto.CoinMarketCapResponse

# %%
dir(data)
# Out:
# ['INVESTMENT_TYPES',
#  'INVESTMENT_TYPES_STR',
#  'QUERY',
#  'URL_SWITCH',
#  'YEARLY_TRADING_DAYS',
#  '_CoinMarketCapResponse__set_dataframe',
#  '_Investment__count',
#  '_Investment__debug',
#  '_Investment__response',
#  '_Investment__validate_investment_list',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'ci_portfolio_print',
#  'closing_portfolio_balance_print',
#  'closing_price_print',
#  'closing_value_print',
#  'coins',
#  'collection_time',
#  'collection_timestamp',
#  'combine_investments_title_str',
#  'create_investment_dict',
#  'currency',
#  'dataframe',
#  'debug',
#  'endpoint',
#  'get_investment_strs',
#  'id',
#  'name',
#  'portfolio',
#  'price',
#  'print_json_dump',
#  'request',
#  'response',
#  'ticker',
#  'time_format',
#  'title',
#  'url',
#  'value']

# %%
data.url
# Out:
# '/Users/danieldeleon/Desktop/Fintech_workspace/Challenge_Homeworks/Global-Crypto-behavior/data/debug_data.json/listings/latest'

# %%
data.print_json_dump()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
display(data)

# %%
data.dataframe.head(50)
# Out:
#       id      name symbol      slug  num_market_pairs  \
# 0      1   Bitcoin    BTC   bitcoin              8935
# 1   1027  Ethereum    ETH  ethereum              5630
# 4   2010   Cardano    ADA   cardano               284
# 6     74  Dogecoin   DOGE  dogecoin               378
# 13     2  Litecoin    LTC  litecoin               710
# 23  2280  Filecoin    FIL  filecoin               148
# 27   328    Monero    XMR    monero               162
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 4   2017-10-01T00:00:00.000Z
# 6   2013-12-15T00:00:00.000Z
# 13  2013-04-28T00:00:00.000Z
# 23  2017-12-13T00:00:00.000Z
# 27  2014-05-21T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [mineable, pow, smart-contracts, ethereum, coi...           NaN
# 4   [mineable, dpos, pos, platform, research, smar...  4.500000e+10
# 6   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 13  [mineable, pow, scrypt, medium-of-exchange, bi...  8.400000e+07
# 23  [mineable, distributed-computing, filesharing,...           NaN
# 27  [mineable, pow, medium-of-exchange, privacy, r...           NaN
#
#     circulating_supply  total_supply platform  cmc_rank  \
# 0         1.878211e+07  1.878211e+07     None         1
# 1         1.170489e+08  1.170489e+08     None         2
# 4         3.209673e+10  3.298224e+10     None         5
# 6         1.307996e+11  1.307996e+11     None         7
# 13        6.675261e+07  6.675261e+07     None        14
# 23        9.536228e+07  9.536228e+07     None        24
# 27        1.797043e+07  1.797043e+07     None        28
#
#                 last_updated  \
# 0   2021-08-10T17:56:02.000Z
# 1   2021-08-10T17:56:02.000Z
# 4   2021-08-10T17:55:09.000Z
# 6   2021-08-10T17:56:03.000Z
# 13  2021-08-10T17:56:02.000Z
# 23  2021-08-10T17:56:04.000Z
# 27  2021-08-10T17:56:04.000Z
#
#                                                 quote
# 0   {'USD': {'price': 45026.29477360262, 'volume_2...
# 1   {'USD': {'price': 3093.334931102753, 'volume_2...
# 4   {'USD': {'price': 1.55979115557864, 'volume_24...
# 6   {'USD': {'price': 0.24798973814074, 'volume_24...
# 13  {'USD': {'price': 161.31597001680163, 'volume_...
# 23  {'USD': {'price': 66.13823922818833, 'volume_2...
# 27  {'USD': {'price': 260.8547681294421, 'volume_2...

# %%
data.dataframe.drop(columns = ["platform"])
# Out:
#       id      name symbol      slug  num_market_pairs  \
# 0      1   Bitcoin    BTC   bitcoin              8935
# 1   1027  Ethereum    ETH  ethereum              5630
# 4   2010   Cardano    ADA   cardano               284
# 6     74  Dogecoin   DOGE  dogecoin               378
# 13     2  Litecoin    LTC  litecoin               710
# 23  2280  Filecoin    FIL  filecoin               148
# 27   328    Monero    XMR    monero               162
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 4   2017-10-01T00:00:00.000Z
# 6   2013-12-15T00:00:00.000Z
# 13  2013-04-28T00:00:00.000Z
# 23  2017-12-13T00:00:00.000Z
# 27  2014-05-21T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [mineable, pow, smart-contracts, ethereum, coi...           NaN
# 4   [mineable, dpos, pos, platform, research, smar...  4.500000e+10
# 6   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 13  [mineable, pow, scrypt, medium-of-exchange, bi...  8.400000e+07
# 23  [mineable, distributed-computing, filesharing,...           NaN
# 27  [mineable, pow, medium-of-exchange, privacy, r...           NaN
#
#     circulating_supply  total_supply  cmc_rank              last_updated  \
# 0         1.878211e+07  1.878211e+07         1  2021-08-10T17:56:02.000Z
# 1         1.170489e+08  1.170489e+08         2  2021-08-10T17:56:02.000Z
# 4         3.209673e+10  3.298224e+10         5  2021-08-10T17:55:09.000Z
# 6         1.307996e+11  1.307996e+11         7  2021-08-10T17:56:03.000Z
# 13        6.675261e+07  6.675261e+07        14  2021-08-10T17:56:02.000Z
# 23        9.536228e+07  9.536228e+07        24  2021-08-10T17:56:04.000Z
# 27        1.797043e+07  1.797043e+07        28  2021-08-10T17:56:04.000Z
#
#                                                 quote
# 0   {'USD': {'price': 45026.29477360262, 'volume_2...
# 1   {'USD': {'price': 3093.334931102753, 'volume_2...
# 4   {'USD': {'price': 1.55979115557864, 'volume_24...
# 6   {'USD': {'price': 0.24798973814074, 'volume_24...
# 13  {'USD': {'price': 161.31597001680163, 'volume_...
# 23  {'USD': {'price': 66.13823922818833, 'volume_2...
# 27  {'USD': {'price': 260.8547681294421, 'volume_2...
