# %% [markdown]
# # Global Crypto Behavior Analyzer

# %%
from market_response.crypto import CoinMarketCapResponse
from utils.json_io          import json_write
cryptocurrencies = {
    "Bitcoin":  ("BTC", "1"),
    "Ethereum": ("ETH", "1027"),
    "Cardano":  ("ADA", "2010"),
    "Litecoin": ("LTC", "2"),
    "Monero":   ("XMR", "328"),
    "Dogecoin": ("DOGE", "74"),
}


slugs, tickers, id = list(zip(*[[x, y, z] for x, (y, z) in cryptocurrencies.items()]))
coins    = 5000
currency = "USD"
endpoint = "latest-quotes"
# debug = "YES" # Uses ../data/debug_datat.json (we want this for testing)
debug = "yes"  # !!! Are you SURE???
# debug = "SANDBOX"

data = CoinMarketCapResponse(tickers, slugs, id, coins, currency, endpoint, debug=debug)

print(data.dataframe.head())
# Out:
# Source : C:\Users\nssen\Desktop\FinTech\Module_Lessons\Week_8\global-crypto-behavior\data\debug_latest-quotes_data.json
# DEBUG : YES
#
#
#   index    id      name symbol      slug num_market_pairs  \
# 0     1     1   Bitcoin    BTC   bitcoin             8935
# 1     2     2  Litecoin    LTC  litecoin              711
# 2    74    74  Dogecoin   DOGE  dogecoin              379
# 3   328   328    Monero    XMR    monero              162
# 4  1027  1027  Ethereum    ETH  ethereum             5610
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2013-04-28T00:00:00.000Z
# 2  2013-12-15T00:00:00.000Z
# 3  2014-05-21T00:00:00.000Z
# 4  2015-08-07T00:00:00.000Z
#
#                                                 tags max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000
# 1  [mineable, pow, scrypt, medium-of-exchange, bi...   84000000
# 2  [mineable, pow, scrypt, medium-of-exchange, me...       None
# 3  [mineable, pow, medium-of-exchange, privacy, r...       None
# 4  [mineable, pow, smart-contracts, ethereum, bin...       None
#
#     circulating_supply         total_supply is_active platform cmc_rank  \
# 0             18783175             18783175         1     None        1
# 1      66752614.515387      66752614.515387         1     None       15
# 2  130813243560.315384  130813243560.315384         1     None        7
# 3      17971161.768036      17971161.768036         1     None       28
# 4        117064497.874        117064497.874         1     None        2
#
#   is_fiat              last_updated  \
# 0       0  2021-08-11T20:04:02.000Z
# 1       0  2021-08-11T20:04:02.000Z
# 2       0  2021-08-11T20:04:03.000Z
# 3       0  2021-08-11T20:04:04.000Z
# 4       0  2021-08-11T20:04:02.000Z
#
#                                                quote
# 0  {'USD': {'price': 46584.7780844161, 'volume_24...
# 1  {'USD': {'price': 174.70230764025925, 'volume_...
# 2  {'USD': {'price': 0.2798593285568, 'volume_24h...
# 3  {'USD': {'price': 275.07627709730235, 'volume_...
# 4  {'USD': {'price': 3257.2354598728443, 'volume_...

# %%
import pandas as pd

# %%
type(data)
# Out:
# market_response.crypto.CoinMarketCapResponse

# %%
dir(data)
# Out:
# ['DEBUG_FILE',
#  'INVESTMENT_TYPES',
#  'INVESTMENT_TYPES_STR',
#  'URL_SWITCH',
#  'YEARLY_TRADING_DAYS',
#  '_CoinMarketCapResponse__config',
#  '_CoinMarketCapResponse__endpoint',
#  '_CoinMarketCapResponse__set_dataframe',
#  '_Investment__count',
#  '_Investment__debug',
#  '_Investment__response',
#  '_Investment__validate_investment_list',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'ci_portfolio_print',
#  'closing_portfolio_balance_print',
#  'closing_price_print',
#  'closing_value_print',
#  'coins',
#  'collection_time',
#  'collection_timestamp',
#  'combine_investments_title_str',
#  'create_investment_dict',
#  'currency',
#  'dataframe',
#  'debug',
#  'get_investment_strs',
#  'id',
#  'name',
#  'portfolio',
#  'price',
#  'print_json_dump',
#  'request',
#  'response',
#  'ticker',
#  'time_format',
#  'title',
#  'url',
#  'value']

# %%
data.url
# Out:
# 'C:\\Users\\nssen\\Desktop\\FinTech\\Module_Lessons\\Week_8\\global-crypto-behavior\\data\\debug_latest-quotes_data.json'

# %%
data.print_json_dump()
# Out:
# {
#     "data": {
#         "1": {
#             "circulating_supply": 18783175,
#             "cmc_rank": 1,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "id": 1,
#             "is_active": 1,
#             "is_fiat": 0,
#             "last_updated": "2021-08-11T20:04:02.000Z",
#             "max_supply": 21000000,
#             "name": "Bitcoin",
#             "num_market_pairs": 8935,
#             "platform": null,
#             "quote": {
#                 "USD": {
#                     "fully_diluted_market_cap": 978280339772.74,
#                     "last_updated": "2021-08-11T20:04:02.000Z",
#                     "market_cap": 875010039095.7524,
#                     "market_cap_dominance": 44.8932,
#                     "percent_change_1h": 0.41887402,
#                     "percent_change_24h": 2.07273693,
#                     "percent_change_30d": 42.33473697,
#                     "percent_change_60d": 30.15791827,
#                     "percent_change_7d": 17.03370042,
#                     "percent_change_90d": -4.06948352,
#                     "price": 46584.7780844161,
#                     "volume_24h": 33864189893.690712
#                 }
#             },
#             "slug": "bitcoin",
#             "symbol": "BTC",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "store-of-value",
#                 "state-channels",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "arrington-xrp-capital",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures",
#                 "galaxy-digital-portfolio",
#                 "huobi-capital",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-xzy-screener"
#             ],
#             "total_supply": 18783175
#         },
#         "1027": {
#             "circulating_supply": 117064497.874,
#             "cmc_rank": 2,
#             "date_added": "2015-08-07T00:00:00.000Z",
#             "id": 1027,
#             "is_active": 1,
#             "is_fiat": 0,
#             "last_updated": "2021-08-11T20:04:02.000Z",
#             "max_supply": null,
#             "name": "Ethereum",
#             "num_market_pairs": 5610,
#             "platform": null,
#             "quote": {
#                 "USD": {
#                     "fully_diluted_market_cap": 381306633567.4,
#                     "last_updated": "2021-08-11T20:04:02.000Z",
#                     "market_cap": 381306633567.402,
#                     "market_cap_dominance": 19.5633,
#                     "percent_change_1h": 0.66610583,
#                     "percent_change_24h": 3.22756724,
#                     "percent_change_30d": 61.7125122,
#                     "percent_change_60d": 34.83001562,
#                     "percent_change_7d": 20.80371913,
#                     "percent_change_90d": -10.44188255,
#                     "price": 3257.2354598728443,
#                     "volume_24h": 26465659679.38901
#                 }
#             },
#             "slug": "ethereum",
#             "symbol": "ETH",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "smart-contracts",
#                 "ethereum",
#                 "binance-smart-chain",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "arrington-xrp-capital",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures",
#                 "hashkey-capital-portfolio",
#                 "kinetic-capital",
#                 "huobi-capital",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-xzy-screener"
#             ],
#             "total_supply": 117064497.874
#         },
#         "2": {
#             "circulating_supply": 66752614.51538747,
#             "cmc_rank": 15,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "id": 2,
#             "is_active": 1,
#             "is_fiat": 0,
#             "last_updated": "2021-08-11T20:04:02.000Z",
#             "max_supply": 84000000,
#             "name": "Litecoin",
#             "num_market_pairs": 711,
#             "platform": null,
#             "quote": {
#                 "USD": {
#                     "fully_diluted_market_cap": 14674993841.78,
#                     "last_updated": "2021-08-11T20:04:02.000Z",
#                     "market_cap": 11661835796.858856,
#                     "market_cap_dominance": 0.5992,
#                     "percent_change_1h": 0.6261592,
#                     "percent_change_24h": 5.75299099,
#                     "percent_change_30d": 31.55346841,
#                     "percent_change_60d": 7.26295429,
#                     "percent_change_7d": 21.38539419,
#                     "percent_change_90d": -41.02828055,
#                     "price": 174.70230764025925,
#                     "volume_24h": 2416933354.5978937
#                 }
#             },
#             "slug": "litecoin",
#             "symbol": "LTC",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "binance-chain",
#                 "binance-smart-chain"
#             ],
#             "total_supply": 66752614.51538747
#         },
#         "2010": {
#             "circulating_supply": 32112369135.143,
#             "cmc_rank": 5,
#             "date_added": "2017-10-01T00:00:00.000Z",
#             "id": 2010,
#             "is_active": 1,
#             "is_fiat": 0,
#             "last_updated": "2021-08-11T20:03:14.000Z",
#             "max_supply": 45000000000,
#             "name": "Cardano",
#             "num_market_pairs": 284,
#             "platform": null,
#             "quote": {
#                 "USD": {
#                     "fully_diluted_market_cap": 83908297572.93,
#                     "last_updated": "2021-08-11T20:03:14.000Z",
#                     "market_cap": 59877649448.072235,
#                     "market_cap_dominance": 3.0767,
#                     "percent_change_1h": -0.27051964,
#                     "percent_change_24h": 17.25131918,
#                     "percent_change_30d": 44.08992857,
#                     "percent_change_60d": 25.82861338,
#                     "percent_change_7d": 34.81016645,
#                     "percent_change_90d": 0.51622139,
#                     "price": 1.86462883495393,
#                     "volume_24h": 6005313766.748243
#                 }
#             },
#             "slug": "cardano",
#             "symbol": "ADA",
#             "tags": [
#                 "mineable",
#                 "dpos",
#                 "pos",
#                 "platform",
#                 "research",
#                 "smart-contracts",
#                 "staking",
#                 "binance-smart-chain"
#             ],
#             "total_supply": 32982237587.058
#         },
#         "328": {
#             "circulating_supply": 17971161.76803567,
#             "cmc_rank": 28,
#             "date_added": "2014-05-21T00:00:00.000Z",
#             "id": 328,
#             "is_active": 1,
#             "is_fiat": 0,
#             "last_updated": "2021-08-11T20:04:04.000Z",
#             "max_supply": null,
#             "name": "Monero",
#             "num_market_pairs": 162,
#             "platform": null,
#             "quote": {
#                 "USD": {
#                     "fully_diluted_market_cap": 4943440274.26,
#                     "last_updated": "2021-08-11T20:04:04.000Z",
#                     "market_cap": 4943440274.264626,
#                     "market_cap_dominance": 0.2536,
#                     "percent_change_1h": 0.434026,
#                     "percent_change_24h": 4.95351116,
#                     "percent_change_30d": 35.05458959,
#                     "percent_change_60d": 10.69101436,
#                     "percent_change_7d": 17.51301868,
#                     "percent_change_90d": -27.25103517,
#                     "price": 275.07627709730235,
#                     "volume_24h": 242106687.6512769
#                 }
#             },
#             "slug": "monero",
#             "symbol": "XMR",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "medium-of-exchange",
#                 "privacy",
#                 "ringct",
#                 "boostvc-portfolio",
#                 "electric-capital-portfolio",
#                 "galaxy-digital-portfolio"
#             ],
#             "total_supply": 17971161.76803567
#         },
#         "74": {
#             "circulating_supply": 130813243560.31538,
#             "cmc_rank": 7,
#             "date_added": "2013-12-15T00:00:00.000Z",
#             "id": 74,
#             "is_active": 1,
#             "is_fiat": 0,
#             "last_updated": "2021-08-11T20:04:03.000Z",
#             "max_supply": null,
#             "name": "Dogecoin",
#             "num_market_pairs": 379,
#             "platform": null,
#             "quote": {
#                 "USD": {
#                     "fully_diluted_market_cap": 36609306509.13,
#                     "last_updated": "2021-08-11T20:04:03.000Z",
#                     "market_cap": 36609306509.12701,
#                     "market_cap_dominance": 1.8783,
#                     "percent_change_1h": 0.43312876,
#                     "percent_change_24h": 9.40969097,
#                     "percent_change_30d": 36.45104109,
#                     "percent_change_60d": -11.32029474,
#                     "percent_change_7d": 39.39925014,
#                     "percent_change_90d": -26.96223235,
#                     "price": 0.2798593285568,
#                     "volume_24h": 4707361530.937372
#                 }
#             },
#             "slug": "dogecoin",
#             "symbol": "DOGE",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "memes",
#                 "payments",
#                 "binance-smart-chain",
#                 "doggone-doggerel"
#             ],
#             "total_supply": 130813243560.31538
#         }
#     },
#     "status": {
#         "credit_count": 1,
#         "elapsed": 21,
#         "error_code": 0,
#         "error_message": null,
#         "notice": null,
#         "timestamp": "2021-08-11T20:04:37.086Z"
#     }
# }

# %%
display(data)

# %%
data.dataframe
# Out:
#   index    id      name symbol      slug num_market_pairs  \
# 0     1     1   Bitcoin    BTC   bitcoin             8935
# 1     2     2  Litecoin    LTC  litecoin              711
# 2    74    74  Dogecoin   DOGE  dogecoin              379
# 3   328   328    Monero    XMR    monero              162
# 4  1027  1027  Ethereum    ETH  ethereum             5610
# 5  2010  2010   Cardano    ADA   cardano              284
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2013-04-28T00:00:00.000Z
# 2  2013-12-15T00:00:00.000Z
# 3  2014-05-21T00:00:00.000Z
# 4  2015-08-07T00:00:00.000Z
# 5  2017-10-01T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...     21000000
# 1  [mineable, pow, scrypt, medium-of-exchange, bi...     84000000
# 2  [mineable, pow, scrypt, medium-of-exchange, me...         None
# 3  [mineable, pow, medium-of-exchange, privacy, r...         None
# 4  [mineable, pow, smart-contracts, ethereum, bin...         None
# 5  [mineable, dpos, pos, platform, research, smar...  45000000000
#
#     circulating_supply         total_supply is_active platform cmc_rank  \
# 0             18783175             18783175         1     None        1
# 1      66752614.515387      66752614.515387         1     None       15
# 2  130813243560.315384  130813243560.315384         1     None        7
# 3      17971161.768036      17971161.768036         1     None       28
# 4        117064497.874        117064497.874         1     None        2
# 5   32112369135.143002   32982237587.057999         1     None        5
#
#   is_fiat              last_updated  \
# 0       0  2021-08-11T20:04:02.000Z
# 1       0  2021-08-11T20:04:02.000Z
# 2       0  2021-08-11T20:04:03.000Z
# 3       0  2021-08-11T20:04:04.000Z
# 4       0  2021-08-11T20:04:02.000Z
# 5       0  2021-08-11T20:03:14.000Z
#
#                                                quote
# 0  {'USD': {'price': 46584.7780844161, 'volume_24...
# 1  {'USD': {'price': 174.70230764025925, 'volume_...
# 2  {'USD': {'price': 0.2798593285568, 'volume_24h...
# 3  {'USD': {'price': 275.07627709730235, 'volume_...
# 4  {'USD': {'price': 3257.2354598728443, 'volume_...
# 5  {'USD': {'price': 1.86462883495393, 'volume_24...

# %%
df = data.dataframe
df = df.reset_index(drop=True)
df.head()
# Out:
#   index    id      name symbol      slug num_market_pairs  \
# 0     1     1   Bitcoin    BTC   bitcoin             8935
# 1     2     2  Litecoin    LTC  litecoin              711
# 2    74    74  Dogecoin   DOGE  dogecoin              379
# 3   328   328    Monero    XMR    monero              162
# 4  1027  1027  Ethereum    ETH  ethereum             5610
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2013-04-28T00:00:00.000Z
# 2  2013-12-15T00:00:00.000Z
# 3  2014-05-21T00:00:00.000Z
# 4  2015-08-07T00:00:00.000Z
#
#                                                 tags max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000
# 1  [mineable, pow, scrypt, medium-of-exchange, bi...   84000000
# 2  [mineable, pow, scrypt, medium-of-exchange, me...       None
# 3  [mineable, pow, medium-of-exchange, privacy, r...       None
# 4  [mineable, pow, smart-contracts, ethereum, bin...       None
#
#     circulating_supply         total_supply is_active platform cmc_rank  \
# 0             18783175             18783175         1     None        1
# 1      66752614.515387      66752614.515387         1     None       15
# 2  130813243560.315384  130813243560.315384         1     None        7
# 3      17971161.768036      17971161.768036         1     None       28
# 4        117064497.874        117064497.874         1     None        2
#
#   is_fiat              last_updated  \
# 0       0  2021-08-11T20:04:02.000Z
# 1       0  2021-08-11T20:04:02.000Z
# 2       0  2021-08-11T20:04:03.000Z
# 3       0  2021-08-11T20:04:04.000Z
# 4       0  2021-08-11T20:04:02.000Z
#
#                                                quote
# 0  {'USD': {'price': 46584.7780844161, 'volume_24...
# 1  {'USD': {'price': 174.70230764025925, 'volume_...
# 2  {'USD': {'price': 0.2798593285568, 'volume_24h...
# 3  {'USD': {'price': 275.07627709730235, 'volume_...
# 4  {'USD': {'price': 3257.2354598728443, 'volume_...

# %%
df["max_supply"] = df["max_supply"].fillna(0).astype(int)

# %%
df["circulating_supply"]= df["circulating_supply"].fillna(0).astype(int)

# %%
df["total_supply"]= df["total_supply"].fillna(0).astype(int)

# %%
df1 = df[['name', 'symbol','num_market_pairs',
        'last_updated', 'quote']]
print(df.columns)
display(df.dtypes)
len(df), df.count()
# Out:
# Index(['index', 'id', 'name', 'symbol', 'slug', 'num_market_pairs',
#        'date_added', 'tags', 'max_supply', 'circulating_supply',
#        'total_supply', 'is_active', 'platform', 'cmc_rank', 'is_fiat',
#        'last_updated', 'quote'],
#       dtype='object')
# index                 object
# id                    object
# name                  object
# symbol                object
# slug                  object
# num_market_pairs      object
# date_added            object
# tags                  object
# max_supply             int32
# circulating_supply     int32
# total_supply           int32
# is_active             object
# platform              object
# cmc_rank              object
# is_fiat               object
# last_updated          object
# quote                 object
# dtype: object
# (6,
#  index                 6
#  id                    6
#  name                  6
#  symbol                6
#  slug                  6
#  num_market_pairs      6
#  date_added            6
#  tags                  6
#  max_supply            6
#  circulating_supply    6
#  total_supply          6
#  is_active             6
#  platform              0
#  cmc_rank              6
#  is_fiat               6
#  last_updated          6
#  quote                 6
#  dtype: int64)

# %%
df1
# Out:
#        name symbol num_market_pairs              last_updated  \
# 0   Bitcoin    BTC             8935  2021-08-11T20:04:02.000Z
# 1  Litecoin    LTC              711  2021-08-11T20:04:02.000Z
# 2  Dogecoin   DOGE              379  2021-08-11T20:04:03.000Z
# 3    Monero    XMR              162  2021-08-11T20:04:04.000Z
# 4  Ethereum    ETH             5610  2021-08-11T20:04:02.000Z
# 5   Cardano    ADA              284  2021-08-11T20:03:14.000Z
#
#                                                quote
# 0  {'USD': {'price': 46584.7780844161, 'volume_24...
# 1  {'USD': {'price': 174.70230764025925, 'volume_...
# 2  {'USD': {'price': 0.2798593285568, 'volume_24h...
# 3  {'USD': {'price': 275.07627709730235, 'volume_...
# 4  {'USD': {'price': 3257.2354598728443, 'volume_...
# 5  {'USD': {'price': 1.86462883495393, 'volume_24...

# %%
df_quote = pd.DataFrame(df1["quote"])
df_quote.dtypes
# Out:
# quote    object
# dtype: object

# %%
all = []
for x in df_quote["quote"]:
#     i = 1
    all.append(x["USD"])
    
new_df = pd.DataFrame(all)

# %%
new_df
# Out:
#           price    volume_24h  percent_change_1h  percent_change_24h  \
# 0  46584.778084  3.386419e+10           0.418874            2.072737
# 1    174.702308  2.416933e+09           0.626159            5.752991
# 2      0.279859  4.707362e+09           0.433129            9.409691
# 3    275.076277  2.421067e+08           0.434026            4.953511
# 4   3257.235460  2.646566e+10           0.666106            3.227567
# 5      1.864629  6.005314e+09          -0.270520           17.251319
#
#    percent_change_7d  percent_change_30d  percent_change_60d  \
# 0          17.033700           42.334737           30.157918
# 1          21.385394           31.553468            7.262954
# 2          39.399250           36.451041          -11.320295
# 3          17.513019           35.054590           10.691014
# 4          20.803719           61.712512           34.830016
# 5          34.810166           44.089929           25.828613
#
#    percent_change_90d    market_cap  market_cap_dominance  \
# 0           -4.069484  8.750100e+11               44.8932
# 1          -41.028281  1.166184e+10                0.5992
# 2          -26.962232  3.660931e+10                1.8783
# 3          -27.251035  4.943440e+09                0.2536
# 4          -10.441883  3.813066e+11               19.5633
# 5            0.516221  5.987765e+10                3.0767
#
#    fully_diluted_market_cap              last_updated
# 0              9.782803e+11  2021-08-11T20:04:02.000Z
# 1              1.467499e+10  2021-08-11T20:04:02.000Z
# 2              3.660931e+10  2021-08-11T20:04:03.000Z
# 3              4.943440e+09  2021-08-11T20:04:04.000Z
# 4              3.813066e+11  2021-08-11T20:04:02.000Z
# 5              8.390830e+10  2021-08-11T20:03:14.000Z

# %%
#frames = [df1,new_df]


df_combined = df1.join(new_df,rsuffix="_quote").drop(columns= ["last_updated_quote","quote"])
df_combined
# Out:
#        name symbol num_market_pairs              last_updated         price  \
# 0   Bitcoin    BTC             8935  2021-08-11T20:04:02.000Z  46584.778084
# 1  Litecoin    LTC              711  2021-08-11T20:04:02.000Z    174.702308
# 2  Dogecoin   DOGE              379  2021-08-11T20:04:03.000Z      0.279859
# 3    Monero    XMR              162  2021-08-11T20:04:04.000Z    275.076277
# 4  Ethereum    ETH             5610  2021-08-11T20:04:02.000Z   3257.235460
# 5   Cardano    ADA              284  2021-08-11T20:03:14.000Z      1.864629
#
#      volume_24h  percent_change_1h  percent_change_24h  percent_change_7d  \
# 0  3.386419e+10           0.418874            2.072737          17.033700
# 1  2.416933e+09           0.626159            5.752991          21.385394
# 2  4.707362e+09           0.433129            9.409691          39.399250
# 3  2.421067e+08           0.434026            4.953511          17.513019
# 4  2.646566e+10           0.666106            3.227567          20.803719
# 5  6.005314e+09          -0.270520           17.251319          34.810166
#
#    percent_change_30d  percent_change_60d  percent_change_90d    market_cap  \
# 0           42.334737           30.157918           -4.069484  8.750100e+11
# 1           31.553468            7.262954          -41.028281  1.166184e+10
# 2           36.451041          -11.320295          -26.962232  3.660931e+10
# 3           35.054590           10.691014          -27.251035  4.943440e+09
# 4           61.712512           34.830016          -10.441883  3.813066e+11
# 5           44.089929           25.828613            0.516221  5.987765e+10
#
#    market_cap_dominance  fully_diluted_market_cap
# 0               44.8932              9.782803e+11
# 1                0.5992              1.467499e+10
# 2                1.8783              3.660931e+10
# 3                0.2536              4.943440e+09
# 4               19.5633              3.813066e+11
# 5                3.0767              8.390830e+10

# %%
df_combined["volume_24h"] = df_combined["volume_24h"].fillna(0).astype(int)

# %%
df_combined["market_cap"] = df_combined["market_cap"].fillna(0).astype(int)

# %%
df_combined["fully_diluted_market_cap"] = df_combined["fully_diluted_market_cap"].fillna(0).astype(int)

# %%
df_combined
# Out:
#        name symbol num_market_pairs              last_updated         price  \
# 0   Bitcoin    BTC             8935  2021-08-11T20:04:02.000Z  46584.778084
# 1  Litecoin    LTC              711  2021-08-11T20:04:02.000Z    174.702308
# 2  Dogecoin   DOGE              379  2021-08-11T20:04:03.000Z      0.279859
# 3    Monero    XMR              162  2021-08-11T20:04:04.000Z    275.076277
# 4  Ethereum    ETH             5610  2021-08-11T20:04:02.000Z   3257.235460
# 5   Cardano    ADA              284  2021-08-11T20:03:14.000Z      1.864629
#
#    volume_24h  percent_change_1h  percent_change_24h  percent_change_7d  \
# 0 -2147483648           0.418874            2.072737          17.033700
# 1 -2147483648           0.626159            5.752991          21.385394
# 2 -2147483648           0.433129            9.409691          39.399250
# 3   242106687           0.434026            4.953511          17.513019
# 4 -2147483648           0.666106            3.227567          20.803719
# 5 -2147483648          -0.270520           17.251319          34.810166
#
#    percent_change_30d  percent_change_60d  percent_change_90d  market_cap  \
# 0           42.334737           30.157918           -4.069484 -2147483648
# 1           31.553468            7.262954          -41.028281 -2147483648
# 2           36.451041          -11.320295          -26.962232 -2147483648
# 3           35.054590           10.691014          -27.251035 -2147483648
# 4           61.712512           34.830016          -10.441883 -2147483648
# 5           44.089929           25.828613            0.516221 -2147483648
#
#    market_cap_dominance  fully_diluted_market_cap
# 0               44.8932               -2147483648
# 1                0.5992               -2147483648
# 2                1.8783               -2147483648
# 3                0.2536               -2147483648
# 4               19.5633               -2147483648
# 5                3.0767               -2147483648

# %%
df_combined["last_updated"]= pd.to_datetime( df_combined["last_updated"],infer_datetime_format=True)

# %%
df_combined
# Out:
#        name symbol num_market_pairs              last_updated         price  \
# 0   Bitcoin    BTC             8935 2021-08-11 20:04:02+00:00  46584.778084
# 1  Litecoin    LTC              711 2021-08-11 20:04:02+00:00    174.702308
# 2  Dogecoin   DOGE              379 2021-08-11 20:04:03+00:00      0.279859
# 3    Monero    XMR              162 2021-08-11 20:04:04+00:00    275.076277
# 4  Ethereum    ETH             5610 2021-08-11 20:04:02+00:00   3257.235460
# 5   Cardano    ADA              284 2021-08-11 20:03:14+00:00      1.864629
#
#    volume_24h  percent_change_1h  percent_change_24h  percent_change_7d  \
# 0 -2147483648           0.418874            2.072737          17.033700
# 1 -2147483648           0.626159            5.752991          21.385394
# 2 -2147483648           0.433129            9.409691          39.399250
# 3   242106687           0.434026            4.953511          17.513019
# 4 -2147483648           0.666106            3.227567          20.803719
# 5 -2147483648          -0.270520           17.251319          34.810166
#
#    percent_change_30d  percent_change_60d  percent_change_90d  market_cap  \
# 0           42.334737           30.157918           -4.069484 -2147483648
# 1           31.553468            7.262954          -41.028281 -2147483648
# 2           36.451041          -11.320295          -26.962232 -2147483648
# 3           35.054590           10.691014          -27.251035 -2147483648
# 4           61.712512           34.830016          -10.441883 -2147483648
# 5           44.089929           25.828613            0.516221 -2147483648
#
#    market_cap_dominance  fully_diluted_market_cap
# 0               44.8932               -2147483648
# 1                0.5992               -2147483648
# 2                1.8783               -2147483648
# 3                0.2536               -2147483648
# 4               19.5633               -2147483648
# 5                3.0767               -2147483648
