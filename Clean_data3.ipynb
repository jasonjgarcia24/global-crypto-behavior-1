# %%
import pandas as pd

# %%
def data_pull(date_var):
    Clean_data_crypto = pd.read_csv(f"./data/api_archive_latest-quotes_data_{date_var}.csv")

# %%
data_crypto_three= pd.read_csv('./data/archive_latest-quotes_data_MANUAL-RUN.csv')

# %%
data_crypto_three
# Out:
#    Unnamed: 0    id      name symbol      slug  num_market_pairs  \
# 0           0     1   Bitcoin    BTC   bitcoin              8935
# 1           1     2  Litecoin    LTC  litecoin               711
# 2           2    74  Dogecoin   DOGE  dogecoin               379
# 3           3   328    Monero    XMR    monero               162
# 4           4  1027  Ethereum    ETH  ethereum              5610
# 5           5  2010   Cardano    ADA   cardano               284
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2013-04-28T00:00:00.000Z
# 2  2013-12-15T00:00:00.000Z
# 3  2014-05-21T00:00:00.000Z
# 4  2015-08-07T00:00:00.000Z
# 5  2017-10-01T00:00:00.000Z
#
#                                                 tags    max_supply  \
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 1  ['mineable', 'pow', 'scrypt', 'medium-of-excha...  8.400000e+07
# 2  ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# ...

# %%
data_crypto_three["max_supply"] = data_crypto_three["max_supply"].fillna(0).astype(int)
data_crypto_three["circulating_supply"]= data_crypto_three["circulating_supply"].fillna(0).astype(int)
data_crypto_three["total_supply"]= data_crypto_three["total_supply"].fillna(0).astype(int)
data_crypto_three["quote.USD.market_cap"]= data_crypto_three["quote.USD.market_cap"].fillna(0).astype(int)
data_crypto_three["quote.USD.fully_diluted_market_cap"]= data_crypto_three["quote.USD.fully_diluted_market_cap"].fillna(0).astype(int)
data_crypto_three["date_added"]= pd.to_datetime( data_crypto_three["date_added"],infer_datetime_format=True)

data_crypto_three["quote.USD.last_updated"] = pd.to_datetime(data_crypto_three["quote.USD.last_updated"],infer_datetime_format=True)

# %%
data_crypto_three.drop(columns = ["id", 
                            "tags", 
                            'max_supply',
                            'circulating_supply',
                            'total_supply',
                            'quote.USD.market_cap', 
                            'quote.USD.market_cap_dominance',
                            'quote.USD.fully_diluted_market_cap',
                            'is_fiat',
                            'platform',
                            'quote.USD.volume_24h',
                            'quote.USD.price',
                            'date_added',])
# Out:
#    Unnamed: 0      name symbol      slug  num_market_pairs  is_active  \
# 0           0   Bitcoin    BTC   bitcoin              8935          1
# 1           1  Litecoin    LTC  litecoin               711          1
# 2           2  Dogecoin   DOGE  dogecoin               379          1
# 3           3    Monero    XMR    monero               162          1
# 4           4  Ethereum    ETH  ethereum              5610          1
# 5           5   Cardano    ADA   cardano               284          1
#
#    cmc_rank              last_updated  quote.USD.percent_change_1h  \
# 0         1  2021-08-11T20:04:02.000Z                     0.418874
# 1        15  2021-08-11T20:04:02.000Z                     0.626159
# 2         7  2021-08-11T20:04:03.000Z                     0.433129
# 3        28  2021-08-11T20:04:04.000Z                     0.434026
# 4         2  2021-08-11T20:04:02.000Z                     0.666106
# 5         5  2021-08-11T20:03:14.000Z                    -0.270520
#
# ...
