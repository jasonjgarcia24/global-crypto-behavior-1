# %%
import pandas as pd

# %%
data_crypto= pd.read_csv('./data/api_archive_latest-quotes_data_20210814.csv')

# %%
data_crypto.head()
# Out:
#      id      name symbol      slug  num_market_pairs  \
# 0     1   Bitcoin    BTC   bitcoin              8911
# 1     2  Litecoin    LTC  litecoin               710
# 2    74  Dogecoin   DOGE  dogecoin               379
# 3   328    Monero    XMR    monero               161
# 4  1027  Ethereum    ETH  ethereum              5602
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2013-04-28T00:00:00.000Z
# 2  2013-12-15T00:00:00.000Z
# 3  2014-05-21T00:00:00.000Z
# 4  2015-08-07T00:00:00.000Z
#
#                                                 tags  max_supply  \
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...  21000000.0
# 1  ['mineable', 'pow', 'scrypt', 'medium-of-excha...  84000000.0
# 2  ['mineable', 'pow', 'scrypt', 'medium-of-excha...         NaN
# 3  ['mineable', 'pow', 'medium-of-exchange', 'pri...         NaN
# 4  ['mineable', 'pow', 'smart-contracts', 'ethere...         NaN
#
#    circulating_supply  total_supply  ...  quote.USD.percent_change_1h  \
# 0        1.878502e+07  1.878502e+07  ...                     2.401659
# 1        6.675261e+07  6.675261e+07  ...                     2.919682
# 2        1.308407e+11  1.308407e+11  ...                     2.243974
# 3        1.797252e+07  1.797252e+07  ...                     1.254455
# 4        1.170926e+08  1.170926e+08  ...                     1.669064
#
#    quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      7.287233                    11.411778
# 1                      9.590786                    21.802303
# 2                      6.808925                    35.593325
# 3                      4.422734                     3.610469
# 4                      7.314847                    12.551944
#
#    quote.USD.percent_change_30d quote.USD.percent_change_60d  \
# 0                     44.849416                    19.416426
# 1                     37.656928                     4.226183
# 2                     42.115482                   -13.360598
# 3                     34.093551                    -0.846900
# 4                     64.483079                    28.726430
#
#    quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -1.290266          8.929674e+11
# 1                    -41.412079          1.208915e+10
# 2                    -45.391997          3.664184e+10
# 3                    -31.873237          4.819994e+09
# 4                    -13.433195          3.836383e+11
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         45.1050                        9.982591e+11
# 1                          0.6106                        1.521271e+10
# 2                          1.8508                        3.664184e+10
# 3                          0.2435                        4.819994e+09
# 4                         19.3542                        3.836383e+11
#
#      quote.USD.last_updated
# 0  2021-08-13T20:57:02.000Z
# 1  2021-08-13T20:57:02.000Z
# 2  2021-08-13T20:57:03.000Z
# 3  2021-08-13T20:57:04.000Z
# 4  2021-08-13T20:57:02.000Z
#
# [5 rows x 27 columns]

# %%
data_crypto["max_supply"] = data_crypto["max_supply"].fillna(0).astype(int)
data_crypto["circulating_supply"]= data_crypto["circulating_supply"].fillna(0).astype(int)
data_crypto["total_supply"]= data_crypto["total_supply"].fillna(0).astype(int)

# %%
data_crypto["quote.USD.market_cap"]= data_crypto["quote.USD.market_cap"].fillna(0).astype(int)
data_crypto["quote.USD.fully_diluted_market_cap"]= data_crypto["quote.USD.fully_diluted_market_cap"].fillna(0).astype(int)

# %%
data_crypto["date_added"]= pd.to_datetime( data_crypto["date_added"],infer_datetime_format=True)
data_crypto["quote.USD.last_updated"] = pd.to_datetime( data_crypto["quote.USD.last_updated"],infer_datetime_format=True)

# %%
data_crypto_one = data_crypto.drop(columns = ["id", 
                            "tags", 
                            'max_supply',
                            'circulating_supply',
                            'total_supply',
                            'quote.USD.market_cap', 
                            'quote.USD.market_cap_dominance',
                            'quote.USD.fully_diluted_market_cap',
                            'is_fiat',
                            'platform',
                            'quote.USD.volume_24h',
                            'quote.USD.price',
                            'date_added'])

# %%
data_crypto_one
# Out:
#           name symbol      slug  num_market_pairs  is_active  cmc_rank  \
# 0      Bitcoin    BTC   bitcoin              8911          1         1
# 1     Litecoin    LTC  litecoin               710          1        13
# 2     Dogecoin   DOGE  dogecoin               379          1         7
# 3       Monero    XMR    monero               161          1        28
# 4     Ethereum    ETH  ethereum              5602          1         2
# ...        ...    ...       ...               ...        ...       ...
# 1495  Litecoin    LTC  litecoin               710          1        14
# 1496  Dogecoin   DOGE  dogecoin               379          1         7
# 1497    Monero    XMR    monero               161          1        29
# 1498  Ethereum    ETH  ethereum              5593          1         2
# 1499   Cardano    ADA   cardano               287          1         3
#
#                   last_updated  quote.USD.percent_change_1h  \
# 0     2021-08-13T20:57:02.000Z                     2.401659
# 1     2021-08-13T20:57:02.000Z                     2.919682
# 2     2021-08-13T20:57:03.000Z                     2.243974
# 3     2021-08-13T20:57:04.000Z                     1.254455
# 4     2021-08-13T20:57:02.000Z                     1.669064
# ...                        ...                          ...
# 1495  2021-08-14T20:08:02.000Z                    -0.411338
# 1496  2021-08-14T20:08:03.000Z                    -0.149246
# 1497  2021-08-14T20:08:04.000Z                     0.291400
# 1498  2021-08-14T20:08:02.000Z                    -0.186210
# 1499  2021-08-14T20:07:08.000Z                     0.210074
#
#       quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                         7.287233                    11.411778
# 1                         9.590786                    21.802303
# 2                         6.808925                    35.593325
# 3                         4.422734                     3.610469
# 4                         7.314847                    12.551944
# ...                            ...                          ...
# 1495                      0.730909                    16.912721
# 1496                      3.386926                    18.529631
# 1497                      0.517278                     1.376277
# 1498                     -0.562994                     5.716050
# 1499                      8.172474                    51.811956
#
#       quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                        44.849416                     19.416426
# 1                        37.656928                      4.226183
# 2                        42.115482                    -13.360598
# 3                        34.093551                     -0.846900
# 4                        64.483079                     28.726430
# ...                            ...                           ...
# 1495                     44.409806                      4.308014
# 1496                     54.621420                     -9.599052
# 1497                     38.995566                     -2.478809
# 1498                     69.208555                     28.847092
# 1499                     78.269874                     41.212567
#
#       quote.USD.percent_change_90d    quote.USD.last_updated
# 0                        -1.290266 2021-08-13 20:57:02+00:00
# 1                       -41.412079 2021-08-13 20:57:02+00:00
# 2                       -45.391997 2021-08-13 20:57:03+00:00
# 3                       -31.873237 2021-08-13 20:57:04+00:00
# 4                       -13.433195 2021-08-13 20:57:02+00:00
# ...                            ...                       ...
# 1495                    -38.252019 2021-08-14 20:08:02+00:00
# 1496                    -43.721893 2021-08-14 20:08:03+00:00
# 1497                    -30.126028 2021-08-14 20:08:04+00:00
# 1498                     -6.014065 2021-08-14 20:08:02+00:00
# 1499                      4.064510 2021-08-14 20:07:08+00:00
#
# [1500 rows x 14 columns]
